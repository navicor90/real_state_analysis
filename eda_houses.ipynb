# %% [markdown]
# ## About this project
#
# Analysis about houses in real state market.
#
# Estadisticos:
# * Cantidad total
# * Precio promedio
# * Precio mediano
# * Dispersion(p99, p1, desviacion tipica)
#
# Abiertas por:
# * Gran Mendoza(General)
# * Departamentos(chacras separado)
# * Inmobiliaria
# * Tipo de precio (Dolar, Peso, no se sabe)
# * Tipo de inmueble (Lote, Departamento, Casa)
# * _Rango de interes_
#
# Lands range size in m2: `[0,300),[300,500),[500,1000),[1000,)`

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import time
import random
import sys
import os
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from utils.inmoclick_clean_utils import fix_clean_total_area,fix_clean_floor_area, bucketizer

# %% [markdown]
# ## 1.0- Loading Data

# %% [markdown]
# ### 1.1- Reading the csv

# %%
filename = "data_source/dataframe_house.csv"
df = pd.read_csv(filename)
df.head(3).T
# Out:
#                                                                0  \
# ref_id                                         inmueble-2233-336
# neighborhood                               Club de Campo Mendoza
# district                                              Guaymallen
# province                                                 Mendoza
# price                                                US$ 410.000
# currency                                                     US$
# amount                                                    410000
# url            /2233-fernandez-aubone/inmuebles/336/ficha/cas...
# description    Inmobiliaria FERNANDEZ AUBONE Vende propiedad ...
# totalArea                                                    400
# bedrooms                                                       3
# bathrooms                                                      3
# floorArea                                                    268
# agency                                          Fernandez Aubone
# property_type                                 PropertyType.HOUSE
# source_web                                             inmoclick
# scrapped_date                                         2020-07-18
#
#                                                                1  \
# ref_id                                         inmueble-2229-597
# neighborhood                                Barrio Cementista II
# district                                               Las Heras
# province                                                 Mendoza
# price                                                US$ 155.000
# currency                                                     US$
# amount                                                    155000
# url            /2229-poblete-inmobiliaria/inmuebles/597/ficha...
# description    Moderna Casa de dos plantas.\nFinos detalles y...
# totalArea                                                    220
# bedrooms                                                       4
# bathrooms                                                      2
# floorArea                                                    190
# agency                                      Poblete Inmobiliaria
# property_type                                 PropertyType.HOUSE
# source_web                                             inmoclick
# scrapped_date                                         2020-07-18
#
#                                                                2
# ref_id                                         inmueble-2435-558
# neighborhood      **B° Ayres de Fader** (s/San Martín), Drummond
# district                                           Lujan de Cuyo
# province                                                 Mendoza
# price                                               $ 14.990.000
# currency                                                       $
# amount                                                 1.499e+07
# url            /2435-ernesto-cordoba-broker-inmobiliario/inmu...
# description    **V.E.N.D.E.** Ernesto CORDOBA (-Broker Inmobi...
# totalArea                                                    475
# bedrooms                                                       3
# bathrooms                                                      3
# floorArea                                                    200
# agency                       Ernesto CORDOBA Broker Inmobiliario
# property_type                                 PropertyType.HOUSE
# source_web                                             inmoclick
# scrapped_date                                         2020-07-18

# %%
print(f'Total df size: {len(df)}')
print(f'Unique ref_ids: {len(df.ref_id.unique())}')
# Out:
# Total df size: 3456
# Unique ref_ids: 3456

# %% [markdown]
# ### 1.2- Selecting just Gran Mendoza data

# %%
df.district.unique()
print(f"Cantidad total de propiedades originales:{len(df)}")
gran_mendoza_list = ['Godoy Cruz', 'Maipu', 'Lujan de Cuyo', 'Las Heras', 'Capital',
       'Carrodilla', 'Guaymallen', 'Chacras de Coria',
       'Vistalba', 'Mayor Drummond', 'Perdriel', 'La Puntilla']
df = df[df.district.isin(gran_mendoza_list)]
print(f"Cantidad total de propiedades en el Gran Mendoza:{len(df)}")
# Out:
# Cantidad total de propiedades originales:3456
# Cantidad total de propiedades en el Gran Mendoza:3330

# %% [markdown]
# ## 2.0- EDA: Houses

# %% [markdown]
# ### 2.1- Composicion por tipo de moneda

# %%
# Fixing nan cases
df.currency = df.currency.fillna('consultar')

curr = df.groupby('currency').count().ref_id.sort_values()
share = round(curr/curr.sum()*100,1)
g = sns.barplot(x=curr.index.values,y=curr.values)
for i,row in enumerate(curr.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(i,row[1], bar_text, color='black', ha="center",va='bottom')
    
g.set_title('Composicion por tipo de moneda')
plt.show()

# %% [markdown]
# ### 2.2- Composicion por distrito

# %%
districts = df.groupby('district').count().ref_id.sort_values(ascending=False)
share = round(districts/districts.sum()*100,1)
g = sns.barplot(x=districts.values,y=districts.index.values)

for i,row in enumerate(districts.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(row[1],i, bar_text, color='black', ha="left",va='center',rotation=0)
g.set_title('Composicion por distrito')
plt.show()

# %% [markdown]
# ### 2.3- Composicion por inmobiliaria

# %%
agency = df.groupby("agency").count().ref_id.sort_values(ascending= False)
share = round(agency/agency.sum()*100,1)
print("total agencies:"+str(len(agency)))

agency = agency.head(30)
plt.figure(figsize=(8,6))
g = sns.barplot(x=agency.values, y=agency.index.values)

for i,row in enumerate(agency.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(row[1],i, bar_text, color='black', ha="left",va='center',rotation=0)
g.set_title('Composicion por Inmobiliaria')
plt.show()
# Out:
# total agencies:232

# %% [markdown]
# ### 2.4- Composicion por inmobililaria - excluyendo reposteo de inmuebles

# %%
duplicated_houses = pd.read_csv("duplicated_houses.csv")
df_dup = df.merge(duplicated_houses,how='left',right_on="ref_id",left_on="ref_id")
df_not_dup = df_dup[df_dup.is_duplicated!=1]
agency = df_not_dup.groupby("agency").count().ref_id.sort_values(ascending= False)
share = round(agency/agency.sum()*100,1)
print("total agencies:"+str(len(agency)))

agency = agency.head(30)
plt.figure(figsize=(8,6))
g = sns.barplot(x=agency.values, y=agency.index.values)

for i,row in enumerate(agency.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(row[1],i, bar_text, color='black', ha="left",va='center',rotation=0)
g.set_title('Composicion por Inmobiliaria - excluyendo re posteos')
plt.show()
# Out:
# total agencies:229

# %% [markdown]
# ### 2.5- totalArea composition
# Rango de superficies para casas en m2:
# * 300..600
# * 600..1000
# * 1000..

# %% [markdown]
# #### 2.5.1-Percent with disabled totalArea

# %%
# Percent of disables
100.0 * len(df[df['totalArea']=='disable'])/len(df)
# Out:
# 11.05105105105105

# %% [markdown]
# #### 2.5.2- Creating buckets with fixed totalArea ranges

# %%
# Fixing totalArea var and casting to double
cleaned_df = fix_clean_total_area(df)

# Creating buckets
bucket_separators = [300,600,1000]
field = "totalArea_fixed"
new_field="house_range"
ranges = bucketizer(cleaned_df, bucket_separators, field, new_field)
ranges
# Out:
# ['0..300', '300..600', '600..1000', '1000..']

# %% [markdown]
# #### 2.5.3 Plotting floorArea ranges composition

# %%
house_range = cleaned_df.groupby('house_range').count().ref_id#.sort_values(ascending=False)
share = round(house_range/house_range.sum()*100,1)
g = sns.barplot(x=ranges, y=house_range.values)

for i,row in enumerate(house_range.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(i, row[1], bar_text, color='black', ha="center",va='bottom',rotation=0)
g.set_title('Composicion por Rangos de Superficie cubierta')
plt.show()

# %% [markdown]
# ### 2.6- floorArea composition
# Rango de superficies cubierta para casas en m2:
# * 90..120
# * 120..240
# * 240..

# %% [markdown]
# #### 2.6.1-Percent with disabled floorArea

# %%
# Percent of floorArea in disable
100.0 * len(df[df['floorArea']=='disable'])/len(df)
# Out:
# 10.99099099099099

# %% [markdown]
# #### 2.6.2- Creating buckets with fixed totalArea ranges

# %%
# Removing disables
cleaned_df = fix_clean_floor_area(df)
# Avoid apartments with less of 10 square meters
cleaned_df = cleaned_df[cleaned_df.floorArea_fixed >= 10]

# Creating buckets
bucket_separators = [90,120,240]
field = "floorArea_fixed"
new_field="house_range"
ranges = bucketizer(cleaned_df, bucket_separators, field, new_field)
ranges
# Out:
# ['0..90', '90..120', '120..240', '240..']

# %% [markdown]
# #### 2.6.3 Plotting floorArea ranges composition

# %%
house_range = cleaned_df.groupby('house_range').count().ref_id#.sort_values(ascending=False)
share = round(house_range/house_range.sum()*100,1)
g = sns.barplot(x=ranges, y=house_range.values)

for i,row in enumerate(house_range.iteritems()):
    bar_text = f'{row[1]} ({share.iloc[i]}%)'
    g.text(i, row[1], bar_text, color='black', ha="center",va='bottom',rotation=0)
g.set_title('Composicion por Rangos de Superficie cubierta')
plt.show()

# %% [markdown]
# ### 2.7 House size buckets vs district: average squared meter price

# %% [markdown]
# #### 2.7.1- Prices without excluding outliers

# %%
cleaned_df["squared_meter_price"] = cleaned_df.amount/cleaned_df.floorArea_fixed

pd.pivot_table(cleaned_df[cleaned_df['currency']=='US$'],
               values=['squared_meter_price','ref_id'],
               index='district',
               columns='house_range',
               aggfunc={'squared_meter_price':'mean',
                        'ref_id':'count'}).style.format("{:.1f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_abe513e4_d38e_11ea_a07e_c809a8598abc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>ref_id</th>        <th class="col_heading level0 col4" colspan=4>squared_meter_price</th>    </tr>    <tr>        <th class="index_name level1" >house_range</th>        <th class="col_heading level1 col0" >0.0</th>        <th class="col_heading level1 col1" >90.0</th>        <th class="col_heading level1 col2" >120.0</th>        <th class="col_heading level1 col3" >240.0</th>        <th class="col_heading level1 col4" >0.0</th>        <th class="col_heading level1 col5" >90.0</th>        <th class="col_heading level1 col6" >120.0</th>        <th class="col_heading level1 col7" >240.0</th>    </tr>    <tr>        <th class="index_name level0" >district</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row0" class="row_heading level0 row0" >Capital</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col0" class="data row0 col0" >16.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col1" class="data row0 col1" >33.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col2" class="data row0 col2" >234.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col3" class="data row0 col3" >193.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col4" class="data row0 col4" >1071.9</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col5" class="data row0 col5" >909.5</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col6" class="data row0 col6" >1029.2</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow0_col7" class="data row0 col7" >1046.2</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row1" class="row_heading level0 row1" >Carrodilla</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col0" class="data row1 col0" >8.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col1" class="data row1 col1" >5.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col2" class="data row1 col2" >30.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col3" class="data row1 col3" >14.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col4" class="data row1 col4" >7095.3</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col5" class="data row1 col5" >943.5</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col6" class="data row1 col6" >959.6</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow1_col7" class="data row1 col7" >832.1</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row2" class="row_heading level0 row2" >Chacras de Coria</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col0" class="data row2 col0" >2.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col1" class="data row2 col1" >7.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col2" class="data row2 col2" >87.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col3" class="data row2 col3" >144.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col4" class="data row2 col4" >1369.3</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col5" class="data row2 col5" >1198.1</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col6" class="data row2 col6" >1050.2</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow2_col7" class="data row2 col7" >991.8</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row3" class="row_heading level0 row3" >Godoy Cruz</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col0" class="data row3 col0" >18.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col1" class="data row3 col1" >31.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col2" class="data row3 col2" >195.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col3" class="data row3 col3" >100.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col4" class="data row3 col4" >670.8</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col5" class="data row3 col5" >666.2</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col6" class="data row3 col6" >716.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow3_col7" class="data row3 col7" >1009.1</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row4" class="row_heading level0 row4" >Guaymallen</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col0" class="data row4 col0" >19.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col1" class="data row4 col1" >49.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col2" class="data row4 col2" >199.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col3" class="data row4 col3" >129.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col4" class="data row4 col4" >679.2</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col5" class="data row4 col5" >768.4</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col6" class="data row4 col6" >777.6</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow4_col7" class="data row4 col7" >889.0</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row5" class="row_heading level0 row5" >La Puntilla</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col0" class="data row5 col0" >nan</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col2" class="data row5 col2" >7.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col3" class="data row5 col3" >6.0</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col4" class="data row5 col4" >nan</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col6" class="data row5 col6" >1119.5</td>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow5_col7" class="data row5 col7" >879.7</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e4_d38e_11ea_a07e_c809a8598abclevel0_row6" class="row_heading level0 row6" >Las Heras</th>
#                         <td id="T_abe513e4_d38e_11ea_a07e_c809a8598abcrow6_col0" class="data row6 col0" >7.0</td>
#                         <td id="T_abe513e

# %% [markdown]
# #### 2.7.2- Prices excluding outliers

# %%
from scipy import stats
dolarized = cleaned_df[cleaned_df['currency']=='US$']
print(f"dolarized with outliers {len(dolarized)}")
z_scores = stats.zscore(dolarized.amount)
abs_z_scores = np.abs(z_scores)
dolarized = dolarized[(abs_z_scores < 3)]

z_scores = stats.zscore(dolarized.floorArea_fixed)
abs_z_scores = np.abs(z_scores)
dolarized = dolarized[(abs_z_scores < 3)]
print(f"dolarized without outliers {len(dolarized)}")
# Out:
# dolarized with outliers 2349
# dolarized without outliers 2326

# %%
pd.pivot_table(dolarized,
               values=['squared_meter_price','ref_id'],
               index='district',
               columns='house_range',
               aggfunc={'squared_meter_price':'mean',
                        'ref_id':'count'}).style.format("{:.1f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_abe513e5_d38e_11ea_a07e_c809a8598abc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>ref_id</th>        <th class="col_heading level0 col4" colspan=4>squared_meter_price</th>    </tr>    <tr>        <th class="index_name level1" >house_range</th>        <th class="col_heading level1 col0" >0.0</th>        <th class="col_heading level1 col1" >90.0</th>        <th class="col_heading level1 col2" >120.0</th>        <th class="col_heading level1 col3" >240.0</th>        <th class="col_heading level1 col4" >0.0</th>        <th class="col_heading level1 col5" >90.0</th>        <th class="col_heading level1 col6" >120.0</th>        <th class="col_heading level1 col7" >240.0</th>    </tr>    <tr>        <th class="index_name level0" >district</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row0" class="row_heading level0 row0" >Capital</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col0" class="data row0 col0" >16.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col1" class="data row0 col1" >33.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col2" class="data row0 col2" >234.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col3" class="data row0 col3" >184.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col4" class="data row0 col4" >1071.9</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col5" class="data row0 col5" >909.5</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col6" class="data row0 col6" >1029.2</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow0_col7" class="data row0 col7" >1013.5</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row1" class="row_heading level0 row1" >Carrodilla</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col0" class="data row1 col0" >7.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col1" class="data row1 col1" >5.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col2" class="data row1 col2" >30.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col3" class="data row1 col3" >14.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col4" class="data row1 col4" >966.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col5" class="data row1 col5" >943.5</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col6" class="data row1 col6" >959.6</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow1_col7" class="data row1 col7" >832.1</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row2" class="row_heading level0 row2" >Chacras de Coria</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col0" class="data row2 col0" >2.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col1" class="data row2 col1" >7.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col2" class="data row2 col2" >87.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col3" class="data row2 col3" >136.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col4" class="data row2 col4" >1369.3</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col5" class="data row2 col5" >1198.1</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col6" class="data row2 col6" >1050.2</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow2_col7" class="data row2 col7" >965.6</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row3" class="row_heading level0 row3" >Godoy Cruz</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col0" class="data row3 col0" >18.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col1" class="data row3 col1" >31.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col2" class="data row3 col2" >195.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col3" class="data row3 col3" >99.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col4" class="data row3 col4" >670.8</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col5" class="data row3 col5" >666.2</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col6" class="data row3 col6" >716.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow3_col7" class="data row3 col7" >999.1</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row4" class="row_heading level0 row4" >Guaymallen</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col0" class="data row4 col0" >19.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col1" class="data row4 col1" >49.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col2" class="data row4 col2" >199.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col3" class="data row4 col3" >129.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col4" class="data row4 col4" >679.2</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col5" class="data row4 col5" >768.4</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col6" class="data row4 col6" >777.6</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow4_col7" class="data row4 col7" >889.0</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row5" class="row_heading level0 row5" >La Puntilla</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col0" class="data row5 col0" >nan</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col2" class="data row5 col2" >7.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col3" class="data row5 col3" >6.0</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col4" class="data row5 col4" >nan</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col6" class="data row5 col6" >1119.5</td>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow5_col7" class="data row5 col7" >879.7</td>
#             </tr>
#             <tr>
#                         <th id="T_abe513e5_d38e_11ea_a07e_c809a8598abclevel0_row6" class="row_heading level0 row6" >Las Heras</th>
#                         <td id="T_abe513e5_d38e_11ea_a07e_c809a8598abcrow6_col0" class="data row6 col0" >7.0</td>
#                         <td id="T_abe513e5_d

# %% [markdown]
# ### 3.0- EDA - Extra info

# %% [markdown]
# ### 3.1 Amount disitribution

# %%
dolarized = df[df.currency=='US$'].copy()
dolarized['truncated_amount'] = dolarized.amount
dolarized.loc[dolarized['amount'] >= 2000000,'truncated_amount']=2000000
dolarized.truncated_amount.hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3.2- Districts distribution

# %%
df.groupby('district').count().plot(y='ref_id',kind='bar', figsize=(6,3))
# Out:
# <AxesSubplot:xlabel='district'>

# %% [markdown]
# ### 3.3- District dolarized rates

# %%
df['dolarized'] = 0
df.loc[df.currency=='US$','dolarized'] = 1
dol_rate = df.groupby('district').agg({'ref_id':'count','dolarized':'sum'}).reset_index()
dol_rate['dolarized_rate']= dol_rate.dolarized/dol_rate.ref_id
dol_rate['not_dolarized_rate']= 1-dol_rate['dolarized_rate']
ax = dol_rate[['district','dolarized_rate','not_dolarized_rate']].plot(x='district', kind='bar', stacked=True)

# %% [markdown]
# ### 3.2- District vs amount

# %%
plt.figure(figsize=(15,8))
g = sns.boxplot(x=dolarized['district'], y=dolarized['truncated_amount'])
g.set_xticklabels(g.get_xticklabels(),rotation=70)
plt.show()
